# %%
from setuptools import setup, find_packages

setup(
    name='amremover_package',
    version='0.1.0',
    author='Victoire Lang',
    author_email='victoire.lang@epfl.ch',
    description='A package for removing atom mapping and canonicalizing reaction SMILES',
    long_description=open('readme.md').read(),
    long_description_content_type='text/markdown',
    url='https://github.com/victoirelang/ppchem/exercices/week_7/exercise_02/amremover_package1',
    packages=find_packages(),
    install_requires=[
        'rdkit',
    ],
    classifiers=[
        'Programming Language :: Python :: 3',
        'License :: OSI Approved :: MIT License',
        'Operating System :: OS Independent',
    ],
    python_requires='>=3.6',
)
# Out:
# ---------------------------------------------------------------------------
# GetoptError                               Traceback (most recent call last)
# File ~/miniconda3/envs/w7_reactions/lib/python3.10/site-packages/setuptools/_distutils/fancy_getopt.py:246, in FancyGetopt.getopt(self, args, object)
#     245 try:
# --> 246     opts, args = getopt.getopt(args, short_opts, self.long_opts)
#     247 except getopt.error as msg:
#
# File ~/miniconda3/envs/w7_reactions/lib/python3.10/getopt.py:95, in getopt(args, shortopts, longopts)
#      94     else:
# ---> 95         opts, args = do_shorts(opts, args[0][1:], shortopts, args[1:])
#      97 return opts, args
#
# File ~/miniconda3/envs/w7_reactions/lib/python3.10/getopt.py:195, in do_shorts(opts, optstring, shortopts, args)
#     194 opt, optstring = optstring[0], optstring[1:]
# --> 195 if short_has_arg(opt, shortopts):
#     196     if optstring == '':
#
# ...

# %%
from setuptools import setup, find_packages

setup(
    name='amremover_package1',
    version='0.1.0',
    author='Victoire Lang',
    author_email='victoire.lang@epfl.ch',
    description='Mon premier package',
    long_description=open('README.md').read(),
    long_description_content_type='text/markdown',
    url='https://github.com/victoirelang/ppchem/exercices/week_7/exercise_02/amremover_package1',
    packages=find_packages(),
    install_requires=[
        'numpy',
        'pandas',
        'matplotlib',
        # Ajoutez ici toutes les dépendances requises par votre package
    ],
    classifiers=[
        'Programming Language :: Python :: 3',
        'License :: OSI Approved :: MIT License',
        'Operating System :: OS Independent',
    ],
    python_requires='>=3.6',
)
# Out:
# ---------------------------------------------------------------------------
# GetoptError                               Traceback (most recent call last)
# File ~/miniconda3/envs/w7_reactions/lib/python3.10/site-packages/setuptools/_distutils/fancy_getopt.py:246, in FancyGetopt.getopt(self, args, object)
#     245 try:
# --> 246     opts, args = getopt.getopt(args, short_opts, self.long_opts)
#     247 except getopt.error as msg:
#
# File ~/miniconda3/envs/w7_reactions/lib/python3.10/getopt.py:95, in getopt(args, shortopts, longopts)
#      94     else:
# ---> 95         opts, args = do_shorts(opts, args[0][1:], shortopts, args[1:])
#      97 return opts, args
#
# File ~/miniconda3/envs/w7_reactions/lib/python3.10/getopt.py:195, in do_shorts(opts, optstring, shortopts, args)
#     194 opt, optstring = optstring[0], optstring[1:]
# --> 195 if short_has_arg(opt, shortopts):
#     196     if optstring == '':
#
# ...
