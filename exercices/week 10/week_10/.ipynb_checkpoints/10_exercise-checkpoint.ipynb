# %% [markdown]
# # Visualization & Analysis of Chemical Data
# This week we will look at a few ways to visualize and analyze chemical data. We already learned some ways to analyze chemical data in weeks 5 and 6 when we got familiar with RDKit. Visualizing through smart ways of plotting data is also a very important part of data analysis, which allows you to get a feeling of your data and to identify patterns.
#
# Frst, let's get some housekeeping out of the way. We will use the same data as in weeks 5 and 6 from ChEMBL and filter it right away by excluding data with missing SMILES and USAN Definitions.

# %%
# some imports
from rdkit import Chem
from rdkit.Chem import PandasTools
import pandas as pd
from pathlib import Path
import os

# %%
# load data
current_file = Path(os.path.abspath(''))
csv_file = current_file.parent / "week_10" / "data.csv"
df = pd.read_csv(csv_file, sep= ";")
df.head()
# Out:
#   Parent Molecule         Name  \
# 0    CHEMBL492491  FENVALERATE
# 1   CHEMBL2103777  THIOPHANATE
# 2   CHEMBL1868702   GESTRINONE
# 3   CHEMBL2104213   DESMENINOL
# 4   CHEMBL1904952    QUAZODINE
#
#                                             Synonyms  \
# 0  BELMARK|FENVALERATE|PHENVALERATE|PYDRIN|S-5602...
# 1                             NSC-170810|THIOPHANATE
# 2  A 46 745|A-46-745|A-46745|DIMETRIOSE|GESTRINON...
# 3               DESMENINOL|METHIONINE HYDROXY ANALOG
# 4                          MJ 1988|MJ-1988|QUAZODINE
#
#                                       Research Codes  Phase Drug Applicants  \
# 0                           S-5602|SD-43775|WL-43775   -1.0             NaN
# 1                                         NSC-170810   -1.0             NaN
# 2  A 46 745|A-46-745|A-46745|R 2323|R-2323|RU 232...    4.0             NaN
# 3                                                NaN   -1.0             NaN
# 4                                    MJ 1988|MJ-1988   -1.0             NaN
#
#            USAN Stem  USAN Year                          USAN Definition  \
# 0                NaN        NaN                                      NaN
# 1                NaN        NaN                                      NaN
# 2  '-estr-; -rinone'     1978.0  estrogens; cardiotonics (amrinone type)
# 3                NaN        NaN                                      NaN
# 4                NaN     1968.0                                      NaN
#
#                   USAN Stem - Substem  ...  Passes Rule of Five  \
# 0                                 NaN  ...                    0
# 1                                 NaN  ...                    1
# 2  '-estr-(-estr-); -rinone(-rinone)'  ...                    1
# 3                                 NaN  ...                    1
# 4                                 NaN  ...                    1
#
#   First In Class            Chirality Prodrug Oral Parenteral Topical  \
# 0              0      Racemic Mixture       0    0          0       0
# 1              0     Achiral Molecule       0    0          0       0
# 2              0  Single Stereoisomer       0    0          0       0
# 3              0      Racemic Mixture       0    0          0       0
# 4              0     Achiral Molecule       0    0          0       0
#
#   Black Box Availability Type  \
# 0         0           Unknown
# 1         0           Unknown
# 2         0           Unknown
# 3         0           Unknown
# 4         0           Unknown
#
#                                               Smiles
# 0  CC(C)C(C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1)c1ccc(C...
# 1             CCOC(=O)NC(=S)Nc1ccccc1NC(=S)NC(=O)OCC
# 2  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3C=...
# 3                                     CSCCC(O)C(=O)O
# 4                           CCc1ncnc2cc(OC)c(OC)cc12
#
# [5 rows x 29 columns]

# %% [markdown]
# If you get the following error in the next cell:
# ```
# AttributeError: module 'pandas.io.formats.format' has no attribute 'get_adjustment'
# ```
# Install pandas version 2.1 with the following command:
# ```
# !pip install pandas==2.1
# ```

# %%
# remove the rows with NaN values for SMILES and USAN Definition
df = df.dropna(subset=["Smiles", "USAN Definition"])
# add molecule objects to the df from SMILES
PandasTools.AddMoleculeColumnToFrame(df, smilesCol="Smiles", molCol="mol")

# %%
df['USAN Definition'].unique()
# Out:
# array(['estrogens; cardiotonics (amrinone type)', 'sympathomimetics',
#        'alpha-adrenoceptor antagonists (benzodioxane derivatives)',
#        'fibrinogen receptor antagonists (glycoprotein IIb/IIIa receptor antagonists)',
#        'antineoplastics (chloroethylamine derivatives)', 'antiandrogens',
#        'endopeptidase inhibitors',
#        'quaternary ammonium derivatives; quaternary ammonium derivatives',
#        'anti-inflammatory agents (salicylic acid derivatives)',
#        'quaternary ammonium derivatives', 'antidiabetics', 'estrogens',
#        'prostaglandins', 'antivirals',
#        'antihyperlipidemics (clofibrate type)',
#        '5-nitrofuran derivatives',
#        'coronary vasodilators (verapamil type)',
#        'iodine-containing contrast media',
#        'anti-inflammatory/analgesic agents (ibuprofen type)',
#        'cholinesterase inhibitors (physostigmine type)',
#        'bronchodilators (phenethylamine derivatives)',
#        'anti-inflammatory agents (acetic acid derivatives)',
#        'systemic antifungals (miconazole type)',
#        'spasmolytic agents (papaverine type)',
#        'anti-inflammatory agents (indomethacin type)',
#        'analgesics (mixed opiate receptor agonists/antagonists)',
#        'antiallergics (cromoglicic acid derivatives)',
#        'antibacterial antibiotics, chloramphenicol analogs',
#        'anti-inflammatory analgesics (phenylbutazone type)',
#        'inhibitors of plasminogen activator inhibitors- type 1',
#        'phosphoro-derivatives', 'tricyclic compounds',
#        'antifungal antibiotics (undefined group)',
#        'cortisone derivatives; steroids (not prednisolone derivatives)',
#        'steroids (androgens, anabolics); antiandrogens',
#        'dopaminergics (butopamine type)',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines): type IV phosphodiesterase',
#        'antihistamines/local vasoconstrictors (antazoline type)',
#        'local anesthetics', 'antianginals (sydnone derivatives)',
#        'potassium channel agonists', 'antipsychotics (haloperidol type)',
#        'antibiotics (Streptomyces strain)',
#        'antihistaminics (histamine-H1 receptor antagonists)',
#        'antiepileptics (hydantoin derivatives)',
#        'barbituric acid derivatives',
#        '5-HT1A receptor agonists/antagonists acting primarily as neuroprotectors',
#        'acaricide/tick repellent', 'antiarrhythmics',
#        'antiprotozoal substances (metronidazole type)',
#        'antidepressants (imipramine type)',
#        'antibiotics (Micromonospora strains)',
#        'H2-receptor antagonists (cimetidine type)',
#        'steroids (not prednisolone derivatives)', 'immunosuppressives',
#        'topical steroids (acetal derivatives)',
#        'antithrombotics, blood coagulation factor XA inhibitors',
#        'antihypertensives (guanidine deriviatives)',
#        'phenylpyridine vasodilators; tricyclic compounds',
#        'angiotensin II receptor antagonists',
#        'benzodiazepine receptor agonists/antagonists',
#        'norepinephrine, serotonin, dopamine, reuptake inhibitor',
#        'thrombin inhibitors (argatroban type)',
#        'tricyclic compounds; antipsychotics (dibenzothiazepine derivatives)',
#        'antihypertensives (ACE inhibitors): antihypertensives (ACE inhibitors), diacid analogs',
#        'enzyme inhibitors', 'atropine derivatives',
#        'antimicrobials (sulfonamides derivatives)',
#        'diagnostic aids ((phenylcarbamoyl) methyl iminodiacetic acid derivatives)',
#        'Fc fusion protein',
#        'diuretics (sulfamoylbenzoic acid derivatives)',
#        'Fc fusion protein; thrombin inhibitors (argatroban type)',
#        'positive inotropic agents (pimobendan type)',
#        'N-methyl-D-asparate (NMDA) receptor antagonist/agonists, glycine recognition site',
#        'antipsychotics (dopamine D2 antagonists)',
#        'sodium channel blockers, signal transduction modulators',
#        'steroids (not prednisolone derivatives); prednisone and prednisolone derivatives',
#        'narcotic antagonists/agonists (6,7-benzomorphan derivatives)',
#        'antivirals: antivirals (acyclovir type)',
#        'ergot alkaloid deriviatives',
#        'hypnotics/tranquilizers (zopiclone type)',
#        'analgesics (meperidine type)', 'endothelin receptor antagonists',
#        'sulpride derivatives and analogs',
#        'cephalosporins; phosphoro-derivatives',
#        'antiulcer agents (benzimidazole derivatives)',
#        'androgens; sympathomimetics', 't-RNA synthetase inhibitors',
#        'cephalosporins', 'antianxiety agents (diazepam type)',
#        'antibiotics (rifamycin derivatives)',
#        'anabolic steroids; steroids (not prednisolone derivatives)',
#        'penicillins',
#        'antiarrhythmic/antianginal/antihypertensive agents, phthalazine like structure',
#        'combined alpha and beta blockers; narcotic agonists/antagonists (normorphine type)',
#        'phosphodiesterase inhibitor',
#        'steroids (androgens, anabolics); bronchodilators (phenethylamine derivatives)',
#        'antineoplastics (thiotepa derivatives)',
#        "antianxiety agents/neuroleptics (4'-fluoro-4-piperidinobutyrophenone derivatives)",
#        'anti-inflammatory agents (acetic acid derivatives): anti-inflammatory; pyrazole acetic acid derivatives',
#        'peptides: inhibition of growth hormone release', 'progestins',
#        'beta-blockers (propranolol type)',
#        'anti-inflammatory agents (salicylic acid derivatives); spasmolytic agents (papaverine type)',
#        'theophylline derivatives', 'antibiotics (Aspergillus strains)',
#        'monoamine oxidase inhibitors (hydrazine derivatives); fluoroquinolone derivatives, nonantibacterial indication (e.g., antineoplastic antibiotics)',
#        'narcotic agonists/antagonists (normorphine type)',
#        'antiarrhythmics (propafenone derivatives)',
#        'anabolic steroids; antiarrhythmic/antianginal/antihypertensive agents, phthalazine like structure',
#        'antibacterials (quinolone derivatives)',
#        'nucleoside antiviral or antineoplastic agents, cytarabine or azarabine derivatives',
#        'non-benzodiazepine anxiolytics, sedatives, hypnotics',
#        'antihyperlipidemic, thyromimetic derivatives',
#        'antineoplastic antibiotics (daunorubicin type)',
#        'antiasthmatics (bradykinin antagonists)',
#        'enzyme inhibitors: aldose-reductase inhibitors',
#        'antihypertensives (ACE inhibitors)', 'peptides',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines)',
#        'combined alpha and beta blockers', 'phospholipase A2 inhibitors',
#        'antivirals; antineoplastics (uridine derivatives)',
#        'immunomodulators', 'pentamidine derivatives/analogues',
#        'gabamimetics', 'potassium channel antagonists', 'vinca alkaloids',
#        'antiestrogens of the clomifene and tamoxifen groups',
#        'steroids (not prednisolone derivatives); topical steroids (acetal derivatives)',
#        'vasodilators (undefined group)', 'anorexiants',
#        'steroids (androgens, anabolics); antiandrogens; vinca alkaloids',
#        'analgesics (mixed opiate receptor agonists/antagonists); estrogens',
#        'benzodiazepine receptor agonists/antagonists; cannabinol derivatives',
#        'natural antibiotics (undefined group)',
#        'ionotropic non-NMDA (N-methyl D-aspartate) glutamate receptors [AMPA (alpha-amino-3-hydroxy-5-methyl-4-isoxazolepropionic acid receptor) and/or KA (kainite antagonist) receptors]: antagonists',
#        'antagonists of GABA (gamma-aminobutyric acid) regulated chloride channels, antiparasitic agents',
#        'serotonin 5-HT3 receptor antagonists',
#        'tricyclic compounds; antivirals', 'exportin 1 inhibitors',
#        'platelet aggregation inhibitors, primarily platelet P2Y12 receptor antagonists',
#        'anabolic steroids',
#        'quaternary ammonium derivatives: neuromuscular blocking agents; quaternary ammonium derivatives: neuromuscular blocking agents',
#        'antineoplastics (mitotic inhibitors; tubulin binders)',
#        'antibacterials (Actinoplanes strains)',
#        'serotonin 5-HT6 receptor inhibitors',
#        'antidepressants (dibenzol[a,d]cycloheptane derivatives)',
#        'ribofuranil derivatives (pyrazofurin type)',
#        'enzyme inhibitors: antihyperlipidemics (HMG-CoA inhibitors)',
#        'antihypertensives (hydrazine-phthalazines); antiarrhythmic/antianginal/antihypertensive agents, phthalazine like structure',
#        'amfetamine derivatives', 'cannabinol derivatives',
#        'enzyme inhibitors: elastase inhibitors',
#        'peroxisome proliferator activiating receptor (PPAR) agonists (not thiazolidene derivatives)',
#        'carbonic anhydrase inhibitors',
#        'iodine-containing contrast media; uracil type antineoplastics; uracil derivatives used as thyroid antagonists and as antineoplastics',
#        'antibacterials, pleuromulin derivatives',
#        'steroids (androgens, anabolics); testosterone reductase inhibitors',
#        'narcotic antagonists/agonists (morphinan derivatives)',
#        'acridine derivatives', 'retinol derivatives',
#        'calcium channel blockers (diltiazem type)',
#        'antimigraine agents (5-HT1 receptor agonists); sumatriptan derivatives',
#        'muscarinic receptor agonists/antagonists; quaternary ammonium derivatives: muscarinic receptor agonists/antagonists',
#        'cyclooxygenase-2 inhibitors',
#        'antineoplastics (camptothecin derivatives)',
#        'antineoplastics, alkylating agents (methane sulfonate derivatives)',
#        'cholecystokinin receptor antagonists',
#        'peptides: synthetic corticotropins',
#        'nootropic agents (learning, cognitive enhancers), piracetam type',
#        'anxiolytics (buspirone type)', 'sphingosine derivatives',
#        'enzyme inhibitors: aldose-reductase inhibitors; enzyme inhibitors: urease inhibitors',
#        'beta3 adrenoreceptor agonists', 'sigma receptor ligands',
#        'antipsychotics (risperidone type)', 'glucokinase activator',
#        'serine/threonine kinase inhibitors',
#        'steriodal compounds acting on progesterone receptors (excluding-gest- compounds); progesterone receptor antagonists',
#        'antibiotics (tetracycline derivatives)',
#        'analgesics (fenamic acid subgroup)',
#        'enzyme inhibitors: matrix metalloprotease inhibitors',
#        'aldosterone antagonists (spironolactone type)',
#        'antithelmintics (tibendazole type)',
#        'quaternary ammonium derivatives; atropine derivatives',
#        'antimetabolites (folic acid derivatives)',
#        'cholecystokinin (CCK) antagonists, antiulcer, anxiolytic agent',
#        'iodine-containing contrast media; enzyme inhibitors: folate hydrolose (also called Prostate Specific Membrane Antigen (PSMA) or glutamate carboxypeptidase II) inhibitors',
#        'peptides: peptides with muranic acid present',
#        'muscarinic receptor agonists/antagonists',
#        'antiviral (arildone derivatives)',
#        'anti-inflammatory agents (anilinonicotinic acid derivatives)',
#        'anthelmintics (undefined group)', 'arotinoid derivatives',
#        'Monoamine oxidase (MAO) inhibitors, type B',
#        'antineoplastics, anthraquinone derivatives',
#        'hepatoprotectives (timonacic type); iodine-containing contrast media',
#        "cholinergic agonists (arecoline derivatives used in treatment of Alzheimer's disease",
#        'Fc fusion protein; steriodal compounds acting on progesterone receptors (excluding-gest- compounds); antibacterials, pristinamycin derivatives',
#        'anti-inflammatory analgesics (phenylbutazone type) Note: INN Stem is-buzone',
#        'enzyme inhibitors: proteolytic enzyme inhibitors',
#        'antiulcer agents (benzimidazole derivatives): proton pump inhibitors',
#        'peptides: parathyroid hormone related peptide',
#        'enzyme inhibitors: tryptophan hydroxylase inhibitors',
#        'antivirals (quinoline derivatives)',
#        'hypnotics/sedatives (zolpidem type)',
#        'narcotic analgesics (fentanyl derivatives)',
#        'hepatoprotectives (timonacic type)',
#        'antibacterials (trimethoprim type), dihydrofolate reductase (DHFR) inhibitors',
#        'steriodal compounds acting on progesterone receptors (excluding-gest- compounds); selective progesterone receptor modulators (SPRM)',
#        'tranquilizers/antiepileptics (propanediol and pentanediol groups)',
#        'antineoplastics; antivirals (zidovudine group) (exception: edoxudine)',
#        'nonsteroidal ligand for the progesterone receptor',
#        'anticoagulants (dicumarol type)',
#        'steroids (androgens, anabolics)',
#        'tachykinin (neurokinin) receptor antagonists: NK1 receptor antagonists',
#        'antibacterial antibiotics, carbapenem derivatives',
#        'renin inhibitors; narcotic agonists/antagonists (normorphine type)',
#        'endopeptidase inhibitors: ACE (angiotensin-1 converting enzyme) and NEP (neutral endopeptidase) inhibitors',
#        'antimalarials (artemisin derivatives)', 'estrogens; progestins',
#        'class III antiarrhythmic agents',
#        'systemic antifungals (miconazole type); phosphoro-derivatives',
#        'antiparasitics (salicylanilide derivatives)',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines): leukotriene receptor antagonists',
#        'antihyperlipidaemics, acyl CoA: cholesterol acyltransferase (ACAT) inhibitors',
#        'progestins; topical steroids (acetal derivatives)',
#        'serotonin 5-HT2 receptor antagonists; atropine derivatives',
#        'phosphoro-derivatives; antivirals; antineoplastics (uridine derivatives)',
#        'antisense oligonucleotides',
#        'Fc fusion protein; alpha-adrenoceptor antagonists (benzodioxane derivatives)',
#        'serotonin 5-HT2 receptor antagonists',
#        'prednisone and prednisolone derivatives',
#        'enzyme inhibitors: nitric oxide synthase inhibitors',
#        'antithrombotics (thromboxane A2 receptor antagonists)',
#        'antibiotics obtained from Streptomyces kanamyceticus (related to kanamycin)',
#        'leukotriene receptor antagonists (treatment of inflammatory skin disorders)',
#        'antivirals: carbocyclic nucleosides',
#        'phosphodiesterase type 5 inhibitors (PDE5) inhibitors: (PDE5) inhibitors containing a sulfonamide moiety',
#        'platelet-activating factor antagonists',
#        'tyrosine kinase inhibitors: tyrosine kinase inhibitors; janus kinase inhibitors',
#        'vasodilators (undefined group); phosphoro-derivatives',
#        'prehormones or hormone-release stimulating peptides: thyrotropin releasing hormone analogues',
#        'antineoplastics (aromatase inhibitors)',
#        'quaternary ammonium derivatives: neuromuscular blocking agents',
#        'antiparasitics (ivermectin type)',
#        'fluoroquinolone derivatives, nonantibacterial indication (e.g., antineoplastic antibiotics)',
#        'diuretics (furosemide type)', 'ferrorportin receptor modulators',
#        'antacid aluminum salts',
#        'antiallergic respiratory tract drugs (xanoxic acid derivatives)',
#        'anticonvulsants; antimigraine (benzoylamino-benzpyran derivatives)',
#        'non-steroid antiandrogens',
#        'non-prostanoid prostaglandin receptor agonists',
#        'antihypertensives (prazosin type)',
#        'anti-inflammatory agents (anthranilic acid derivatives) and their salts or esters',
#        'phosphoro-derivatives; antihypertensives (ACE inhibitors): antihypertensives (ACE inhibitors), diacid analogs',
#        'muscarinic receptor antagonists',
#        'antibacterials (quinoline dioxide derivatives)',
#        'antidiabetics; class III antiarrhythmic agents',
#        'antimycobacterials (diaminodiphenylsulfone derivatives)',
#        'diuretics (thiazide derivatives)', 'beta-lactamase inhibitors',
#        'cholesterol sequestrants (glycosides)',
#        'phosphoro-derivatives; cytostatic phospholipid derivatives',
#        'iodine-containing contrast media; sulpride derivatives and analogs',
#        'enzyme inhibitors: aldose-reductase inhibitors; enzyme inhibitors: antihyperlipidemics (HMG-CoA inhibitors)',
#        'antimycotics (pyridone derivatives)', 'androgens',
#        'anti-inflammatory agents (isoxicam type)',
#        'progestins; steroids (androgens, anabolics); antiandrogens',
#        'antivirals: HIV protease inhibitors (saquinavir type)',
#        'caspase inhibitors',
#        'uracil type antineoplastics; uracil derivatives used as thyroid antagonists and as antineoplastics',
#        'monobactam antibiotics', '5-lipoxygenase inhibitors',
#        'selective serotonin reuptake inhibitors (SSRI)',
#        'hypoglycemics (phenformin type)',
#        'antianxiety agents (diazepam type); phosphoro-derivatives',
#        'aromatase inhibitors (imidazole/triazole derivatives); antimicrobials (sulfonamides derivatives)',
#        'ionotropic non-NMDA (N-methyl D-aspartate) glutamate receptors [AMPA (alpha-amino-3-hydroxy-5-methyl-4-isoxazolepropionic acid receptor) and/or KA (kainite antagonist) receptors]; endopeptidase inhibitors: ACE (angiotensin-1 converting enzyme) and NEP (neutral endopeptidase) inhibitors',
#        'general inhalation anesthetics (halogenated alkane derivatives)',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines): leukotriene biosynthesis inhibitors',
#        'phosphoro-derivatives; antivirals: non-nucleoside reverse transcriptase inhibitors, not benzoxazinone derivatives',
#        'peptides: peptides used as pulmonary surfactants',
#        'antihyperlipidemics (clofibrate type); anti-inflammatory agents (salicylic acid derivatives)',
#        'vasoconstrictors (vasopressin derivatives)',
#        'rapidly accelerated fibrosarcoma (RAF) kinase inhibitors',
#        'narcotic agonists/antagonists (normorphine type); enzyme inhibitors: aldose-reductase inhibitors',
#        'vitamin D analogs',
#        'prehormones or hormone-release stimulating peptides: growth hormone-release stimulating peptides',
#        'calcium metabolism regulators',
#        'diuretics (ethacrynic acid derivatives)',
#        'synthetic analogs of the dolastatin series',
#        'antiarrhythmics (disopyramide derivatives)',
#        'lipoprotein lipase activators',
#        'inhibitor of the menin-MLL (KMT2A) receptor',
#        'reactive nitrogen and/or oxygen species redox modulators',
#        'prehormones or hormone-release stimulating peptides',
#        'tyrosine kinase inhibitors',
#        'phlorozin derivatives, phenolic glycosides',
#        'enzyme inhibitors: xanthine oxidase/dehydrogenase inhibitors',
#        'antidepressants (fluoxetine type)',
#        'microsomal triglyceride transfer protein (MTP) inhibitors',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines): leukotriene receptor antagonists; narcotic agonists/antagonists (normorphine type)',
#        'cardiotonics (amrinone type)',
#        'non-steriodal anti-inflammatory agents, fenbufen derivatives',
#        'antirheumatics (lobenzarit type)',
#        'benzodiazepine receptor agonists, partial agonists, inverse agonists (quinolone derivatives)',
#        'estrogens; estrogen antagonists',
#        'quaternary ammonium derivatives; quaternary ammonium derivatives; anti-inflammatory agents (salicylic acid derivatives)',
#        'renin inhibitors', 'antiseptics (dapabutan type)',
#        'phosphoro-derivatives; isophosphoramide mustard derivatives',
#        'antivirals: serine protease inhibitors',
#        'peroxisome proliferator activiating receptor (PPAR) agonists (thiazolidene derivatives)',
#        'phosphoro-derivatives; vinca alkaloids',
#        'analgesics (mixed opiate receptor agonists/antagonists); anti-inflammatory agents (salicylic acid derivatives)',
#        'catechol-O-methyltransferase (COMT) inhibitors',
#        'cortisone derivatives',
#        'antivirals/antiparkinsonians (adamantane derivatives)',
#        'protein tyrosine phosphatase 1B inhibitors',
#        'thalidomide derivatives',
#        'antianxiety, antidepressant inhibitor of norepinephrine and dopamine re-uptake',
#        'ileal bile acid transporter (IBAT) inhibitors',
#        'dopamine receptor agonists',
#        'tachykinin (neurokinin) receptor antagonists: NK3 receptor antagonists',
#        'antivirals; antivirals, chemokine receptor (CCR) antagonists',
#        'antimigraine, serotonin 5-HT1 receptor agonists',
#        'antiestrogens of the clomifene and tamoxifen groups; atropine derivatives',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines); Fc fusion protein',
#        'phosphoro-derivatives; phosphoro-derivatives; anti-inflammatory agents (salicylic acid derivatives)',
#        'antibiotics (Streptomyces strain); antivirals',
#        'multidrug resistance inhibitors: acridine carboxamide derivatives',
#        'antidiabetics; peptides',
#        'estrogens; antineoplastics (chloroethylamine derivatives)',
#        'antiviral (arildone derivatives); phosphoro-derivatives',
#        'anthelmintics (undefined group); anti-inflammatory agents (salicylic acid derivatives)',
#        'immunomodulators: napthyridine analogs',
#        'steroids (not prednisolone derivatives); steroids (androgens, anabolics)',
#        'hormone-release inhibiting peptides', 'oxytocin derivatives',
#        'erythromycin derivatives lacking antibiotic activity; motilin agonists',
#        'serotonin receptor antagonists and partial agonists',
#        'hepatoprotectants, di-isopropyl (1,3-dithiol-2-ylidene) propanedioate and related compounds',
#        'vitamin D analogs; ergot alkaloid deriviatives',
#        'peptides: neuropeptide Y (NPY) receptors and analogues',
#        'tyrosine kinase inhibitors: tropomyosin receptor kinase (TRK) inhibitors',
#        'cephalosporins; quaternary ammonium derivatives; quaternary ammonium derivatives',
#        'steriodal compounds acting on progesterone receptors (excluding-gest- compounds); steroids (androgens, anabolics); testosterone reductase inhibitors',
#        'phosphatidylinositol 3-kinase (PI3K) inhibitors',
#        'amfetamine derivatives; iodine-containing contrast media',
#        'blood substitutes and/or diagnostics (perfluorochemicals)',
#        'ryanodine receptor modulators',
#        'quaternary ammonium derivatives; quaternary ammonium derivatives; atropine derivatives',
#        'phosphoro-derivatives; anti-inflammatory agents (salicylic acid derivatives)',
#        'guanaline cyclase activators',
#        'anabolic steroids; platelet aggregation inhibitors, primarily platelet P2Y12 receptor antagonists',
#        'cortisone derivatives; topical steroids (acetal derivatives)',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines): integrin antagonists',
#        'cephalosporins; endopeptidase inhibitors',
#        'Fc fusion protein; antihyperlipidaemics, acyl CoA: cholesterol acyltransferase (ACAT) inhibitors',
#        'sulpride derivatives and analogs; atropine derivatives',
#        'tricyclic compounds; Rauwolfia alkaloid derivatives',
#        'phosphoro-derivatives; dopaminergics (butopamine type)',
#        'nonsteroidal anti-inflammatory agents (tenidap type)',
#        'maytansinoid derivatives', 'cathespin inhibitors',
#        'aptamers, classical and mirror; peptides',
#        'cephalosporins; quaternary ammonium derivatives',
#        'tranquilizers/antiepileptics (propanediol and pentanediol groups); barbituric acid derivatives',
#        '5-lipoxygenase-activating protein (FLAP) inhibitors',
#        'proton pump inhibitors, not dependent on acid activation',
#        'hypoglycemics (phenformin type); phosphoro-derivatives',
#        'barbituric acid derivatives; vinca alkaloids',
#        'aromatase inhibitors (imidazole/triazole derivatives)',
#        'phenylpyridine vasodilators; Fc fusion protein; tricyclic compounds',
#        'analgesics (mixed opiate receptor agonists/antagonists); steroids (not prednisolone derivatives)',
#        'endopeptidase inhibitors; vinca alkaloids',
#        'complement receptor antagonists/complement inhibitors',
#        'estrogens; endopeptidase inhibitors',
#        'enzyme inhibitors: glutaminase inhibitor',
#        'cyclosporin derivatives',
#        'antivirals/antiparkinsonians (adamantane derivatives); growth hormone derivatives',
#        'steriodal compounds acting on progesterone receptors (excluding-gest- compounds); angiotensin II receptor antagonists',
#        'iodine-containing contrast media; steroids (androgens, anabolics); bronchodilators (phenethylamine derivatives)',
#        'combined alpha and beta blockers; anti-inflammatory agents (salicylic acid derivatives)',
#        'enzymes',
#        'class III antiarrhythmic agents; anti-inflammatory agents (salicylic acid derivatives)',
#        'aptamers, classical and mirror', 'oxazolidinone antibacterials',
#        'immunostimulants',
#        "acetylcholinesterase inhibitors used in the treatment of Alzheimer's disease",
#        'gonadotropin releasing hormone (GnRH) receptor antagonists (nonpeptide)',
#        'histamine H3 receptor antagonists',
#        'cortisone derivatives; steroids (androgens, anabolics); antiandrogens',
#        'tyrosine kinase inhibitors: tyrosine kinase inhibitors; MEK (MAPK kinase) inhibitors',
#        'anti-inflammatory agents (salicylic acid derivatives); vinca alkaloids',
#        'cannabinol derivatives: CB (e.g., CB, CB2, etc.) cannabinoid receptor antagonists',
#        'thrombopoetin agonists',
#        'tricyclic histaminic-H1 receptor antagonists, loratadine derivatives (formerly-tadine)',
#        'enzyme inhibitors: acetyl CoA carboxylase (ACC) inhibitors',
#        'CRF-1 (corticotropin releasing factor) receptor antagonists',
#        'phosphoro-derivatives; antivirals: RNA polymerase (NS5B) inhibitors',
#        'narcotic agonists/antagonists (normorphine type); tricyclic compounds',
#        'antineoplastics, taxane derivatives',
#        'enkephalin agonists (various indications)',
#        'peptides: inhibition of growth hormone release; chelating agents',
#        'dopamine receptor agonists; phosphoro-derivatives',
#        'inhibitors of the ADAM (A disintegrin and A metalloprotease) enzymes (sheddases)',
#        'antineoplastics (arabinofuranosyl derivatives)',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines): thromboxane A2 receptor antagonists',
#        'anthelmintics (undefined group): 2-deoxoparaherquamide A derivatives',
#        'heat-shock protein inducers, bimoclomal type',
#        'Fc fusion protein; phospholipase A2 inhibitors',
#        'immunomodulators; anti-inflammatory agents (salicylic acid derivatives)',
#        'angiogenesis inhibitors',
#        'steriodal compounds acting on progesterone receptors (excluding-gest- compounds); antibacterials, pristinamycin derivatives',
#        'enzyme inhibitors: histone deacetylase inhibitors',
#        'Amyloid beta (Abeta) binders',
#        'enzyme inhibitors: beta secretase inhibitors',
#        'nociceptin opion receptor (NOP) agonists',
#        'phosphodiesterase 10 (PDE10) inhibitors',
#        'antihrombotic indirect selective synthetic factor Xa inhibitors',
#        'uracil type antineoplastics',
#        'antidiabetic, sodium glucose co-transporter 2 (SGLT2) inhibitors, not phlorozin derivatives',
#        'selective melatonin receptor agonist',
#        'adenosine A receptor agonists', 'oxytocin antagonists',
#        'antibiotics, DNA gyrase and topoisomerase IV inhibitors',
#        'proteozome inhibitors', 'monoamine transport inhibitors',
#        'antivirals: respiratory syncytial virus (RSV) fusion inhibitors',
#        'pteridine derivatives',
#        'nicotinic acetylcholine receptor partial agonists/agonists',
#        'enzyme inhibitors: anti-fibrotic/cyclophilin inhibitor',
#        'diuretics (piretanide type)',
#        'phosphoro-derivatives; antibiotics (Streptomyces strain)',
#        'chemokine (C-X-C motif) receptor 2 (CXCR2) modulators',
#        'bcl-2 (B-cell lymphoma 2) inhibitors', 'kinesin inhibitors',
#        'deuterated compounds',
#        'endopeptidase inhibitors: neutral endopeptidase inhibitors possessing additional endothelin converting enzyme inhibitory activity',
#        'antivirals: inhibitor of COVID 3CL protease',
#        'antineoplastic thymidylate synthetase inhibitors',
#        'antivirals: glucosidase inhibitors',
#        'mutated isocitrate dehydrogenase (IDH) inhibitors',
#        'filamin A binders',
#        'cyclin dependent kinase inhibitors (formerly-cidib)',
#        'tyrosine kinase inhibitors: epidermal growth factor receptor (EGFR) inhibitors',
#        'spleen tyrosine kinase (Syk) inhibitors',
#        'antidepressants (fluoxetine type): thioether derivatives',
#        'metabotropic glutamate receptor antagonists, negative allosteric modulators',
#        'trace amine associated receptor (TAAR) agonists',
#        'antivirals: inhibitor of functional assembly of viral core proteins',
#        'anti-inflammatory agents (salicylic acid derivatives); anti-inflammatory agents (salicylic acid derivatives)',
#        'antibiotics (oxacefalosporanic acid derivatives)',
#        'camphorsulfonic acid derivatives used as UVA sunscreens',
#        'enzyme inhibitors: hypoxia-inducible factor (HIF) prolyl hydroxylase inhibitors',
#        'aptamers, classical and mirror; peptides: gap junction protein channel modulators',
#        'extra-terminal motif (BET) family of bromodomain (BRD) proteins',
#        'immunomodulators: mitogen-activated protein (MAP) kinase inhibitors',
#        'benzodiazepine receptor agonists/antagonists; iodine-containing contrast media',
#        'aptamers, classical and mirror; vasopressin receptor antagonists',
#        'enzyme inhibitors: gamma secretase inhibitors',
#        'peptides: platelet aggregation inhibitor (GPIIb/IIIa receptor antagonist)',
#        "tyrosine kinase inhibitors: tyrosine kinase inhibitors Bruton's (Btk) inhibitors",
#        'antivirals: non-nucleoside reverse transcriptase inhibitors, not benzoxazinone derivatives',
#        'dipeptidyl aminopeptidase-IV inhibitors',
#        'enzyme inhibitors: histone deacetylase inhibitors; vinca alkaloids',
#        'immunomodulators: immunomodulators, toll-like receptor agonists',
#        'cholesterol ester transfer protein inhibitors',
#        'skeletal muscle troponin activator',
#        'narcotic agonists/antagonists (normorphine type); antihypertensives (ACE inhibitors)',
#        'inhibitor of apoptosis protein (IAP)',
#        'tachykinin (neurokinin) receptor antagonists: NK2 receptor antagonists',
#        'heat shock protein inhibitors',
#        'estrogen receptor beta agonist; cannabinol derivatives',
#        'ionotropic non-NMDA (N-methyl D-aspartate) glutamate receptors [AMPA (alpha-amino-3-hydroxy-5-methyl-4-isoxazolepropionic acid receptor) and/or KA (kainite antagonist) receptors]; poly-ADP-ribose polymerase inhibitors',
#        'glucocorticoid receptor agonists ( not glucocorticoids); phosphoro-derivatives',
#        'antivirals: RNA polymerase (NS5B) inhibitors',
#        'peptides: melanocortin receptor agonists',
#        'melanocortin-1 receptor (MC1R) agonists',
#        'enzyme inhibitors: glucosyltransferase inhibitors',
#        'adenosine receptor antagonists',
#        'antivirals: nonstructural protein 5A (NS5A) inhibitors',
#        'peptides: atrial natriuretic type substances',
#        'hedgehog signaling inhibitors',
#        'antivirals: viral capsid inhibitors',
#        'Fc fusion protein; antibiotics (Streptomyces strain)',
#        'transient receptor potential antagonists; vanilloid 1 receptor antagonists',
#        'poly-ADP-ribose polymerase inhibitors',
#        'dopamine D1-like receptors (e.g., D1 and D5 subtypes) agonists/partial agonists and potentiators',
#        'local anesthetics; penicillins',
#        'potassium channel antagonists: mixed sodium/potassium channel blockers',
#        'iodine-containing contrast media; atropine derivatives',
#        'Kirsten rat sarcoma (KRAS) inhibitors',
#        'antiarrhythmics: indicates high iodine content',
#        'phosphodiesterase type 9 (PDE9) inhibitors',
#        'calcitonin gene-related peptide receptor antagonists',
#        'iodine-containing contrast media; diuretics (sulfamoylbenzoic acid derivatives)',
#        'deuterated compounds; tyrosine kinase inhibitors',
#        'antimicrobial, bactericidal permeability increasing polypeptide',
#        'phosphoro-derivatives; antiepileptics (hydantoin derivatives)',
#        'extracellular signal regulated kinase (ERK) types 1 and 2 inhibitors (formerly-xertinib)',
#        'phosphoro-derivatives; tyrosine kinase inhibitors',
#        'antivirals: adenosine analogs acting as RNA polymerase inhibitors',
#        'enzyme inhibitors: gastrointestinal lipase inhibitors',
#        'vitamin D analogs; anti-inflammatory agents (salicylic acid derivatives)',
#        'antagonist of the glucagon receptor',
#        'antivirals: neuraminidase inhibitors',
#        'aptamers, classical and mirror; antihypertensives (ACE inhibitors)',
#        'antineoplastics (rebeccamycin derivatives)',
#        'antivirals: integrase inhibitors',
#        'antivirals: treatments of SARS-CoV-2 infection, inhibiting viral RNA replication',
#        'aptamers, classical and mirror; antibiotics (Streptomyces strain)',
#        'peptides: (prostate-specific membrane antigen) PSMA binding peptide; chelating agents',
#        'survival motor neurin SMN1 and SMN2 splicing modulators',
#        'cystic fibrosis transmembrane regulator (CFTR) protein modulators',
#        'vasodilators (undefined group); antiarrhythmic/antianginal/antihypertensive agents, phthalazine like structure',
#        'glucocorticoid receptor antagonists (not glucocorticoids)',
#        'opener of large conductance calcium-activated (maxi-K) potassium channels',
#        'vancomycin-related compounds',
#        'retinol derivatives; tyrosine kinase inhibitors',
#        'calcium receptor antagonists',
#        'aptamers, classical and mirror; pteridine derivatives',
#        'antineoplastics, apoptosis inducing sulfonamide',
#        'multidrug resistance inhibitors: ciclosporin D derivatives',
#        'serum amyloid P (SAP) inhibitors', 'polymers',
#        'peptides: glucagon-like peptide (GLP) analogs',
#        'spermine and/or homospermine derivatives or analogs',
#        'boroles, boron compounds',
#        'androgens; steroids (androgens, anabolics); antiandrogens',
#        'allosteric modulators of small-conductance calcium activated potassium (SK) channels; viral capsids',
#        'maytansinoid derivatives; peptides: inhibition of growth hormone release',
#        'antibiotics (carbacephem derivatives)',
#        'N-methyl D-aspartate (NMDA) receptor antagonists (N2B subunit)',
#        'sodium-hydrogen antiporter (also called sodium-proton exchanger) inhibitors',
#        'deuterated compounds; tyrosine kinase inhibitors: tyrosine kinase inhibitors; janus kinase inhibitors',
#        'Chemokine receptor (CCR) antagonists, not antivirals',
#        'cardiac myosin activator',
#        'tricyclic compounds; antibiotics (rifamycin derivatives)',
#        'vasodilators (undefined group); prostaglandins',
#        'glucagon-like peptide receptor agonists',
#        'enzyme inhibitors: glutathione-s- transferase inhibitors',
#        'androgens; steroids (not prednisolone derivatives)',
#        'antihistaminics (histamine-H1 receptor antagonists); vinca alkaloids',
#        'enzyme inhibitors: small ubiquitin-like modifier inhibitor',
#        'multidrug resistance inhibitors: quinoline derivatives',
#        'vitamin D analogs; antibiotics (Streptomyces strain)',
#        'enzyme inhibitors: autotaxin inhibitors',
#        'prostaglandin receptor antagonists, non prostinoid structure',
#        'PPAR delta receptor agonists', 'pyruvate kinase activators',
#        'analgesics (mixed opiate receptor agonists/antagonists); beta-blockers (propranolol type)',
#        'kappa opiod receptor antagonists', 'CXCR receptor antagonists',
#        'enzyme inhibitors: 1) kallikrein inhibitors or 2) serine protease inhibitors',
#        'deuterated compounds; antiasthmatics (bradykinin antagonists)',
#        'nitrogen oxide (eg., nitrxyl and nitric oxide) donors; prostaglandins',
#        'toll-like receptor antagonists',
#        'ionotropic non-NMDA (N-methyl D-aspartate) glutamate receptors [AMPA (alpha-amino-3-hydroxy-5-methyl-4-isoxazolepropionic acid receptor) and/or KA (kainite antagonist) receptors]: modulators',
#        'multidrug resistance inhibitors: pipecolic acid derivatives',
#        'anticonvulsants; antimigraine (benzoylamino-benzpyran derivatives); cannabinol derivatives',
#        'selective androgen receptor modulator (non-steroidal)',
#        'mitochondrial benzodiazepine receptor (MBR) selective, partial, or inverse agonists (purine derivatives)',
#        'aldehyde traps',
#        'antineoplastics (mitotic inhibitors; tubulin binders); cannabinol derivatives',
#        'histamine H4 receptor antagonists',
#        'antiarrhythmics (ajmaline derivatives)',
#        'enzyme inhibitors: indoleamine 2, 3-dioxygenase 1 (IDO1) inhibitors',
#        'antagonists of the transient receptor potential channel (TRP), melatsatin (TRPM) type; transient receptor potential antagonists',
#        'peptides: peptides with prostate cancer indications',
#        'urotensin receptor antagonists',
#        'phosphoro-derivatives; tachykinin (neurokinin) receptor antagonists: NK1 receptor antagonists',
#        'antiarrhythmics (ajmaline derivatives); quaternary ammonium derivatives',
#        'phosphodiesterase type 9 (PDE9) inhibitors; vinca alkaloids',
#        'antineoplastics, pro-apoptotic cGMP phosphodiesterase inhibitors, sulindac metabolites',
#        'steriodal compounds acting on progesterone receptors (excluding-gest- compounds)',
#        'benzoporphyrin derivatives', 'depsipeptide derivatives',
#        'retinoid-related orphan receptor-γt (RORγt) antagonists/inverse agonists',
#        'mycolic acid inhibitors',
#        'peptides: gastrointestinal functions; normalizing agent',
#        'antimyloidotics', 'peptides: antiviral peptides; antivirals',
#        'dopamine D2D3 receptor modulators',
#        'anticoagulants (hirudin type)',
#        'enzyme inhibitors: partial fatty acid oxidation (pFOX) inhibitor',
#        'serotonin 5-HT3 receptor antagonists; atropine derivatives',
#        'tricyclic compounds; atropine derivatives',
#        'phosphoro-derivatives; oxazolidinone antibacterials',
#        'nitrogen oxide (eg., nitrxyl and nitric oxide) donors',
#        'enzyme inhibitors: dopamine b-hydrolase (DBH) inhibitors',
#        'enzyme inhibitors: Cluster of differentiation (CD) inhibitors (alternative: CD73 inhibitors)',
#        'tachykinin (neurokinin) receptor antagonists: neurotensin receptor antagonists',
#        'receptor for advanced glycation endproducts (RAGE) inhibitors',
#        'ergot alkaloid deriviatives; phlorozin derivatives, phenolic glycosides',
#        'phosphoro-derivatives; immunomodulators',
#        'ubiquitin ligase inhibitors',
#        'silent mating type information regulator (SIRT1) receptor agonists',
#        'antihypertensives (guanidine deriviatives); alpha-adrenoceptor antagonists (benzodioxane derivatives)',
#        'antineoplastic, acylfulvene derivatives',
#        'cephalosporins; vancomycin-related compounds',
#        'farnesyl transferase inhibitor', 'epothilones',
#        'estrogen receptor beta agonist',
#        'cephalosporins; opioid receptor antagonists',
#        'serotonin 5-HT receptor agonists, not principally 5-HT2',
#        'E-selectin antagonists', 'anabolic steroids; enzyme inhibitors',
#        'vasodilators (undefined group): Rho protein kinase (ROCK) inhibitors',
#        'organoarsenic compounds',
#        'glucocorticoid receptor agonists ( not glucocorticoids)',
#        'alpha1- and alpha2- adrenoreceptor agonists',
#        'Fc fusion protein; antivirals: non-nucleoside reverse transcriptase inhibitors; benzoxazinone derivatives',
#        'growth hormone derivatives', 'antibiotics (polyene derivatives)',
#        'heat shock protein inhibitors; narcotic agonists/antagonists (normorphine type)',
#        'cannabinol derivatives; enzyme inhibitors: beta secretase inhibitors',
#        'antagonists of heparin and/or low molecular weight heparins',
#        'antivirals: cyclosporine derivatives',
#        'narcotic agonists/antagonists (normorphine type); antihypertensives (ACE inhibitors): antihypertensives (ACE inhibitors), diacid analogs',
#        'neurotoxic protein translation inhibitors',
#        'antipsychotic with binding activity on sertonin (5-HT2A) and dopamine (D2) receptors',
#        'warfarin analogs',
#        'vinca alkaloids; WNT (wingless-type mouse mammary tumor virus) pathway inhibitors',
#        'enzyme inhibitors: squalene synthase inhibitors',
#        'antiarrhythmic/antianginal/antihypertensive agents, phthalazine like structure; anti-inflammatory agents (salicylic acid derivatives)',
#        'antineoplastics (chloroethylamine derivatives); prednisone and prednisolone derivatives',
#        'coagulation factor XIa inhibitors',
#        'allosteric cardiac myosin modulators', 'FimH (E.coli) blockers',
#        'ecteinascidin derivatives',
#        'enzyme inhibitors: folate hydrolose (also called Prostate Specific Membrane Antigen (PSMA) or glutamate carboxypeptidase II) inhibitors',
#        'antiviral (arildone derivatives); cephalosporins',
#        'PEGylated compounds, covalent attachment of macrogol (polyethylene glycol) polymer; tyrosine kinase inhibitors',
#        'prehormones or hormone-release stimulating peptides; antineoplastic antibiotics (daunorubicin type)',
#        'aptamers, classical and mirror; ergot alkaloid deriviatives',
#        'liver X nuclear hormone (LXR) receptor agonists',
#        'systemic antifungals (miconazole type); Fc fusion protein',
#        'phosphoro-derivatives; antineoplastics; antivirals (zidovudine group) (exception: edoxudine)',
#        'cytochrome bc1 complex inhibitors in mycobacterium tuberculosis',
#        'enzyme inhibitors: D-amino acid oxidase (DAAO) inhibitors',
#        'Kirsten rat sarcoma (KRAS) inhibitors; anti-inflammatory agents (salicylic acid derivatives)',
#        'phosphoro-derivatives; antivirals',
#        'enzyme inhibitors: DNA polymerase',
#        'phosphatidylinositol 3-kinase (PI3K) inhibitors; narcotic agonists/antagonists (normorphine type)',
#        "Src homology 2-containing inositol-5' phosphatase 1 (SHIP1) activators",
#        'angiogenesis inhibitors; small interfering RNA (siRNA)',
#        'histone acetyltransferase inhibitors, targeting the bromodomain acetyl transferase proteins adenoviral E1A-binding protein (p300) and cAMP-responsive element binding protein (CREB) binding protein (CBP)',
#        'inosine monophosphate dehydrogenase inhibitors',
#        'non-peptidic growth hormone secretagogues',
#        'epithelial sodium channel (ENaC) inhibitors, amiloride derivatives',
#        'enzyme inhibitors: fatty acid synthase inhibitors',
#        'phosphoro-derivatives; pteridine derivatives',
#        'calcium-sensing receptor (CaSR) agonists',
#        'PEGylated compounds, covalent attachment of macrogol (polyethylene glycol) polymer; antineoplastics (camptothecin derivatives)',
#        'glycine transporter/reuptake inhibitors',
#        'antivirals: antiviral, disrupts viral maturation',
#        'antibiotics (Streptomyces strain); antibiotics (rifamycin derivatives)',
#        'anti-inflammatory agents (salicylic acid derivatives); cholinesterase inhibitors (physostigmine type)',
#        'anti-inflammatory agents (salicylic acid derivatives); bronchodilators (phenethylamine derivatives)',
#        'vasodilators (undefined group): calcium channel blockers acting as vasodilators',
#        'kinase inhibitor, binds to myristoyl binding site',
#        'phosphodiesterase type 1 (PDE1) ihibitors',
#        'phosphoro-derivatives; antimycotics (pyridone derivatives)',
#        'ergot alkaloid deriviatives; vinca alkaloids',
#        'narcotic agonists/antagonists (normorphine type); 5-HT1A receptor agonists/antagonists acting primarily as neuroprotectors',
#        'antihypertensives (guanidine deriviatives); cannabinol derivatives',
#        '-',
#        'nucleoside antiviral or antineoplastic agents, cytarabine or azarabine derivatives; phosphoro-derivatives',
#        'anti-inflammatory agents (salicylic acid derivatives); peptides',
#        'thalidomide derivatives: zinc finger protein degradation inducing thalidomide derivatives',
#        'androgen receptor inhibitor, N-terminal domain inhibitor',
#        'antibiotics (Streptomyces strain); anti-inflammatory agents (salicylic acid derivatives)',
#        'antibiotics (tetracycline derivatives); phosphoro-derivatives; anti-inflammatory agents (salicylic acid derivatives)',
#        'dopamine D2 receptor modulator',
#        'phosphoro-derivatives; antivirals: HIV protease inhibitors (saquinavir type)',
#        'antiarrhythmic/antianginal/antihypertensive agents, phthalazine like structure; anti-inflammatory agents (salicylic acid derivatives); antimicrobials (sulfonamides derivatives)',
#        'thymidylate synthase inhibitors (benzindole derivatives)',
#        'retinol binding protein 4 (RBP4) antagonists',
#        'hypoxia-inducible factor (HIF) inhibitors',
#        'phosphoro-derivatives; cytostatic phospholipid derivatives; iodine-containing contrast media',
#        'inducers of ribosomal readthrough on nonsense mutation mRNA stop codons',
#        'neuropeptide Y5 antagonists',
#        'peptides: amylin derivatives or mimics',
#        'growth hormone derivatives; enzyme inhibitors: antihyperlipidemics (HMG-CoA inhibitors)',
#        'chelating agents',
#        'angiogenesis inhibitors; phosphoro-derivatives',
#        'antibiotics, diarylquinoline structure',
#        'Protease-activated receptor 1 (PAR1) antagonists',
#        'serotonin 5-HT1B receptor inhibitors',
#        'antifungals, triterpinoids',
#        'nootropic agents (learning/cognitive enhancers), purine derivatives',
#        'peptides: zonulin antagonists',
#        'enzyme inhibitors: heparin derivatives',
#        'deuterated compounds; non-steroid antiandrogens',
#        'neuronal apoptosis inhibitors; glyceraldehyde-3-phosphate dehydrogenase (GAPDH)',
#        'urate transporter inhibitors',
#        'analgesics (mixed opiate receptor agonists/antagonists); gabamimetics',
#        'peptides: oxyntomodulin analogs',
#        'selectin antagonists inhibiting all selectin types',
#        'enzyme inhibitors: lanosterol 14a-demethylase inhibitors',
#        'phosphoro-derivatives; antihypertensives (ACE inhibitors)',
#        'opioid receptor antagonists',
#        'farnesoid X receptor agonists; farnesoid X receptor agonists',
#        'tachykinin (neurokinin) receptor antagonists: NK3 receptor antagonists; vinca alkaloids',
#        'narcotic agonists/antagonists (normorphine type); bronchodilators (phenethylamine derivatives)',
#        'agonists of the Gardos channel, or the calcium activated potassium channel of intermediate conductance',
#        'thalidomide derivatives; narcotic agonists/antagonists (normorphine type)',
#        'phosphoro-derivatives; hepatocyte growth factor (HGF)-MET agonists',
#        'quaternary ammonium derivatives; vinca alkaloids',
#        'antiasthmatics/antiallergics (not acting primarily as antihistamines); vasodilators (undefined group)',
#        'antineoplastics (mitotic inhibitors; tubulin binders); phosphoro-derivatives',
#        'enzyme inhibitors: s-nitrosoglutathione reductase (GSNOR) inhibitors',
#        'deuterated compounds; narcotic antagonists/agonists (morphinan derivatives)',
#        'serotonin receptor agonists, primarily 5-HT2'], dtype=object)

# %% [markdown]
# For the purpose of this exercise we will filter out some specific drugs based on their USAN definition. We picked these four mode of actions: *antivirals*, *analgesics*, *beta-blockers* and *anti-inflammatory* drugs. We will keep any data point that has these words in their description and then make four new super classes out of them stored in `application`. You are free to choose different classes and test the influence on the results below. Depending on the homogeneity of the groups the clustering will give very different results.

# %%
drug_applications = ['antivirals', 'analgesics', 'beta-blockers','anti-inflammatory']
# df matches one of the applications (not contains but exact match)
df = df[df['USAN Definition'].str.contains('|'.join(drug_applications), case=False, na=False)]
# add a column with the application combining all antivirals etc. into one class each
df['application'] = df['USAN Definition'].apply(lambda x: [app for app in drug_applications if app in x.lower()][0])

# %% [markdown]
# ## Principal Component Analysis (PCA)
# Principal Component Analysis (PCA) is a technique used to emphasize variation and bring out strong patterns in a dataset. It's often used to make data easy to explore and visualize. It is also used for dimensionality reduction, which is useful when you have a lot of features describing your data. PCA is a linear transformation method that finds the directions (principal components) that maximize the variance in the data. These directions are orthogonal to each other and form a new coordinate system in which the data can be represented. The first principal component is the direction in which the data varies the most, the second principal component is the direction in which the data varies the second most, and so on. We will plot the first two principal components of the data and thus reduce the dimnesionality of the data (going from n to 2 dimensions). For more details have a look at [this blog post](https://towardsdatascience.com/principal-component-analysis-pca-explained-visually-with-zero-math-1cbf392b9e7d).
#
# We will perform PCA on Morgan fingerprints as features and make use of an the package `molplotly`, which allows plotting data interactively!

# %%
# !pip install molplotly
# !pip install dash==2.10
# !pip install scikit-learn
# Out:
# Requirement already satisfied: molplotly in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (1.1.7)
# Requirement already satisfied: dash>=2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (2.10.0)
# Requirement already satisfied: werkzeug>=2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (2.2.3)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (0.4.2)
# Requirement already satisfied: plotly>=5.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (5.22.0)
# Requirement already satisfied: rdkit-pypi>=2021.9.4 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (2022.9.5)
# Requirement already satisfied: pandas in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (2.1.4)
# Requirement already satisfied: ipykernel in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (6.29.2)
# Requirement already satisfied: nbformat in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from molplotly) (5.9.2)
# Requirement already satisfied: Flask<=2.2.3,>=1.0.4 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash>=2.0.0->molplotly) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash>=2.0.0->molplotly) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash>=2.0.0->molplotly) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash>=2.0.0->molplotly) (5.0.0)
# Requirement already satisfied: requests in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jupyter-dash>=0.4.2->molplotly) (2.31.0)
# Requirement already satisfied: retrying in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jupyter-dash>=0.4.2->molplotly) (1.3.4)
# Requirement already satisfied: ipython in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jupyter-dash>=0.4.2->molplotly) (8.22.1)
# Requirement already satisfied: ansi2html in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jupyter-dash>=0.4.2->molplotly) (1.9.1)
# Requirement already satisfied: nest-asyncio in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jupyter-dash>=0.4.2->molplotly) (1.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from plotly>=5.0.0->molplotly) (8.3.0)
# Requirement already satisfied: packaging in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from plotly>=5.0.0->molplotly) (23.2)
# Requirement already satisfied: numpy in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from rdkit-pypi>=2021.9.4->molplotly) (1.26.4)
# Requirement already satisfied: Pillow in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from rdkit-pypi>=2021.9.4->molplotly) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from werkzeug>=2.0.0->molplotly) (2.1.5)
# Requirement already satisfied: appnope in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (0.1.6)
# Requirement already satisfied: psutil in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipykernel->molplotly) (5.14.1)
# Requirement already satisfied: fastjsonschema in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from nbformat->molplotly) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from nbformat->molplotly) (4.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from pandas->molplotly) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from pandas->molplotly) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from pandas->molplotly) (2024.1)
# Requirement already satisfied: Jinja2>=3.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Flask<=2.2.3,>=1.0.4->dash>=2.0.0->molplotly) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Flask<=2.2.3,>=1.0.4->dash>=2.0.0->molplotly) (2.2.0)
# Requirement already satisfied: click>=8.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Flask<=2.2.3,>=1.0.4->dash>=2.0.0->molplotly) (8.1.7)
# Requirement already satisfied: decorator in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (2.17.2)
# Requirement already satisfied: stack-data in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->molplotly) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->molplotly) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->molplotly) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->molplotly) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->molplotly) (4.2.0)
# Requirement already satisfied: six>=1.5 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->molplotly) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from requests->jupyter-dash>=0.4.2->molplotly) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from requests->jupyter-dash>=0.4.2->molplotly) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from requests->jupyter-dash>=0.4.2->molplotly) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from requests->jupyter-dash>=0.4.2->molplotly) (2024.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.2->molplotly) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.2->molplotly) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash>=0.4.2->molplotly) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->molplotly) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->molplotly) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from stack-data->ipython->jupyter-dash>=0.4.2->molplotly) (0.2.2)
# Requirement already satisfied: dash==2.10 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (2.10.0)
# Requirement already satisfied: Flask<=2.2.3,>=1.0.4 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash==2.10) (2.2.3)
# Requirement already satisfied: Werkzeug<=2.2.3 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash==2.10) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash==2.10) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash==2.10) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash==2.10) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from dash==2.10) (5.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Flask<=2.2.3,>=1.0.4->dash==2.10) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Flask<=2.2.3,>=1.0.4->dash==2.10) (2.2.0)
# Requirement already satisfied: click>=8.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Flask<=2.2.3,>=1.0.4->dash==2.10) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from plotly>=5.0.0->dash==2.10) (8.3.0)
# Requirement already satisfied: packaging in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from plotly>=5.0.0->dash==2.10) (23.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from Werkzeug<=2.2.3->dash==2.10) (2.1.5)
# Requirement already satisfied: scikit-learn in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages (from scikit-learn) (3.5.0)

# %%
# more imports
import numpy as np
from rdkit.Chem import AllChem, DataStructs
from sklearn.decomposition import PCA

# %% [markdown]
# ### Carry out PCA algorithm

# %%
def smi_to_fp(smi):
    '''
    Function to convert SMILES to Morgan fingerprint
    '''
    fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=2048)
    arr = np.zeros((0,), dtype=np.int8)
    DataStructs.ConvertToNumpyArray(fp, arr)
    return arr

# %%
# convert SMILES to Morgan fingerprints
df['fp'] = df['Smiles'].apply(smi_to_fp)
fps = np.array(df['fp'].tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # convert SMILES to Morgan fingerprints
# ----> 2 df['fp'] = df['Smiles'].apply(smi_to_fp)
#       3 fps = np.array(df['fp'].tolist())
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/ppchem/lib/python3.10/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[8], line 5, in smi_to_fp(smi)
#       1 def smi_to_fp(smi):
#       2     '''
#       3     Function to convert SMILES to Morgan fingerprint
#       4     '''
# ----> 5     fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=2048)
#       6     arr = np.zeros((0,), dtype=np.int8)
#       7     DataStructs.ConvertToNumpyArray(fp, arr)
#
# NameError: name 'mol' is not defined

# %% [markdown]
# Look up [here](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html) how to use `sklearn`'s PCA.

# %%
# instantiate PCA class with 2 (principal) components
pca = # TODO code here
# fit and transform our data (fingerprints)
components = pca.fit_transform(fps.reshape(-1, 2048))
# store components in dataframe
df['PCA-1'] = # TODO code here to get first components
df['PCA-2'] = # TODO code here to get second components

# %% [markdown]
# ### Plot the first two principal components
# We already now how to plot data in a straight-forward way using `matplotlib`. While, it is very flexible we have very complex data and would like to see the influence of the molecular structure on the results. Therefore, we will look into the package[ `molplotly`](https://github.com/wjm41/molplotly/tree/main), which allows interactive plotting including much more information.

# %%
import matplotlib.pyplot as plt

# plot the PCA components in a scatter plot
fig, ax = plt.subplots()
scatter = # TODO code here to plot PCA-1 vs PCA-2
ax.set_xlabel('PCA-1');
ax.set_ylabel('PCA-2');

# %% [markdown]
# This is the most basic implementation of such a PCA plot. If you like you can try to populate with more data such as colouring by drug types. In the next step we will look at how this is done with [`molplotly`](https://github.com/wjm41/molplotly/tree/main).

# %%
import plotly.express as px
import molplotly

# TODO: fill in the names of the columns that are needed for the plot (as strings)

# instantiate the plot as done with the base package plotly
fig_pca = px.scatter(df, # data to pull from
                     x=, # x-axis
                     y=, # y-axis
                     color=, # column to color by (drug action)
                     title='PCA of morgan fingerprints', # title of the plot
                     labels={'color': XXXX}, # label for the color legend (same as "color")
                     width=1200,
                     height=800)

# populate with molecule information
app_pca = molplotly.add_molecules(fig=fig_pca,  # figure to populate
                                  df=df,  # dataframe with molecule information
                                  smiles_col=,  # column with SMILES
                                  title_col='Name',  # column to take the name for the molecule when hovering over it
                                  caption_cols=['USAN Definition'], # columns to take the additional captions from
                                  color_col=, # column to color by
                                  show_coords=False)

# show the plot: don't use the same port several times as it will overwrite the previous one
app_pca.run_server(mode='inline', port=8100, height=850)

# %% [markdown]
# Now, this plot is already much more informative. We can see the different drug groups and when hovering over the plot we can see the molecule the data point represents including the full USAN Definition and the name of the drug. We can also zoom in and out again!
#
# This plot showed colouring based on discrete groups. What happens when we want to plot a continuous variable? We will look into this in the next section by calculating the logP of all the molecules.

# %%
from rdkit.Chem import Descriptors

df["LogP"] = # TODO code here to calculate LogP

# %%
import plotly.express as px
import molplotly

# TODO fill in the missing column names and color by logP this time

fig_pca = px.scatter(df,
                     x=,
                     y=,
                     color=,
                     title='PCA of morgan fingerprints',
                     labels={'color': XXXX},
                     width=1200,
                     height=800)

app_pca = molplotly.add_molecules(fig=fig_pca,
                                  df=df,
                                  smiles_col=,
                                  title_col='Name',
                                  caption_cols=['application'],
                                  color_col=,
                                  show_coords=False)

app_pca.run_server(mode='inline', port=8200, height=850)

# %% [markdown]
# This looks interesting too! However, we can see that there are some outliers that make the visulaization not so informative (and a s a side note also are not clustered very well with their group). Let's exclude those points and look at the plot again.

# %%
# filter out logP below -5 and above 5
df_fil = df[(df['LogP'] > -5) & (df['LogP'] < 5)]

# %%
# TODO repeat the same thing as above but with the filtered dataframe
# TODO don't forget to change the port number

# %% [markdown]
# In this last plot the differences in logP can be more easily observed. We can see that there is some trend that the clustering coincides with the logP. This is a very interesting observation but much more analysis would have to be done to get to the depths of this. This is a very simple example of how to use PCA to visualize and analyze chemical data. There are many more ways to use PCA and many more ways to visualize the data. We will look at some more in the next section.

# %% [markdown]
# ## Clustering
# Clustering data is a way to group data points that are similar to each other. There are many different clustering algorithms, and we will look at the k-means algorithm and the Taylor-Butina algorithm. Clsutering is mostly used when we don't know the underlying data structure and need it for analysis or data processing. Another use case is evaluating how meaningful our chosen representation (in our case the Morgan fingerprint) in the given context (here drug actions) is.

# %% [markdown]
# ### K-means clustering
# First, we will look into clustering using the k-means algorithm, which is simple and widely used. It tries to find cluster centers that are representative of certain regions of the data. The algorithm alternates between assigning data points to the nearest cluster center (based on some distance function) and updating cluster centers to be the mean of the data points that are assigned to them. We will use the [`KMeans`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) class from the `sklearn` package to perform k-means clustering.

# %%
# even more imports
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# define number of clusters based on number of drug actions
num_clusters = # TODO What is the number of broad drug actions

# TDOD instantiate KMeans object with num_clusters, a random state of 42 and n_init='auto'
km = # TODO code here

# fit data
fp_km = df['fp'].tolist()
# TODO code here to fit the data (fp_km)

# predict cluster number on our dat
clusters = # TODO code here

# %%
# store in dataframe
df['cluster'] = clusters
# convert to strings (so that it recognizes this as discrete classes)
df['cluster'] = df['cluster'].astype(str)

# %%
# plot the pca and color by cluster
fig_pca_clusters = # TODO code here to plot PCA-1 vs PCA-2 and color by cluster

app_pca_clusters = # TODO code here to add molecules to the plot

app_pca_clusters.run_server(mode='inline', port=8400, height=850)

# %% [markdown]
# Nice! If we compare to the previous plots, there certainly is some overlap with the true clusters. However, we also can see that it is far from perfect. This can have a multitude of reasons. Our drug classes contain heterogenous data, the Morgan fingerprints might not be the best representation of the data, or the clustering algorithm might not be the best choice. We will look into one of the classes next and see how diverse even one class is. Remember that we also comboned several USAN Definitions to simplify things. Thus, different molecule classes (defined by chemical motifs) were taken together.

# %% [markdown]
# #### Finding number of clusters
# In the example above, we knew how many clusters we have in our data so we could help the algorithm by already supplying it with the right number. Now, we will look into how to find the right number of clusters in an unsupervised (without true labels) way and try to cluster the subgroup of all anti-inflammatory drugs.
#
# We will use the Silhouette score to find the optimal number of clusters. The Silhouette score is a measure of how similar an object is to its own cluster (cohesion) compared to other clusters (separation). The score ranges from -1 to 1, where a high value indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters. We will calculate the Silhouette score for different numbers of clusters and choose the number of clusters that gives the highest score.

# %%
# get all the anti-inflammatory drugs
antiinfl = df[df['application'] == 'anti-inflammatory'].copy()
antiinfl.head()

# %%
# let's cluster the data with a random guess of numbers of clusters
num_clusters = 10

# †ODO code here to intantiate, fit and predict the clusters using KMeans as above

antiinfl['cluster'] = clusters
# convert to strings
antiinfl['cluster'] = antiinfl['cluster'].astype(str)

# %%
# we need to repeat the PCA for the subselection of data
pca = PCA(n_components=2)
fsp_antinfl = np.array(antiinfl['fp'].tolist())
components = pca.fit_transform(fsp_antinfl.reshape(-1, 2048))
antiinfl['PCA-1'] = components[:, 0]
antiinfl['PCA-2'] = components[:, 1]

# %% [markdown]
# Show another interactive plot and color by newly determined cluster identity.

# %%
fig_pca = # TODO code here to plot PCA-1 vs PCA-2 and color by cluster

app_pca = # TODO code here to add molecules to the plot

app_pca.run_server(mode='inline', port=8500, height=850)

# %% [markdown]
# Looks good! Let's have a more rational approach on determining the number of clusters. We will iterate over a range of 3 to 34 number of clusters and calculate the [`silhouette score`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html). We will choose the number of clusters where the silhouette score is the highest. We can also plot the silhouette score over the cluster size.

# %%
cluster_range = range(3,35)
score_list = []

for k in cluster_range:
    # instantiate KMeans class
    km = # TODO code here

    # fit and predict km based on the fingerprints
    cluster_labels = # TODO code here

    # calculate the silhouette score (between fP and cluster_labels)
    score = # TODO code here
    score_list.append([k,score])

# %%
# plot silhouette score over number of clusters
score_df = pd.DataFrame(score_list,columns=['k','silhouette_score'])
fig, ax = plt.subplots()
ax.plot(score_df['k'],score_df['silhouette_score']);

# %%
# let's determine the optimal cluster size programmatically
num_clusters_opt = score_df[score_df['silhouette_score'] == score_df['silhouette_score'].max()]['k'].values[0]
num_clusters_opt

# %% [markdown]
# We have the optimal cluster number determined to be 4. We can rerun the k-means algorithm with the optimal number of clusters.

# %%
km_opt = KMeans(n_clusters=num_clusters_opt, random_state=42, n_init="auto")
clusters_opt = km_opt.fit_predict(antiinfl['fp'].tolist())
antiinfl['cluster_opt'] = clusters_opt
# convert to strings
antiinfl['cluster_opt'] = antiinfl['cluster_opt'].astype(str)

# %%
fig_pca = # TODO code here to plot PCA-1 vs PCA-2 and color by "optimal" clusters

app_pca = # TODO code here to add molecules to the plot

app_pca.run_server(mode='inline', port=8600, height=850)

# %% [markdown]
# This looks pretty convincing. We can see that the clustering is much better than before. However, we can also see that there are still some data points that are still clustered in a weird way. This is a very common problem in clustering and can have many reasons but does not mean that anything went wrong with the clustering. As mentioned the before, the data representation has a huge influence but also the way that we visualize it is important. We will look into another clustering algorithm in the next section to see a last approach.

# %% [markdown]
# ### Taylor-Butina clustering
# Now. let's look at a different clustering algorithm, the Taylor-Butina clustering algorithm. This algorithm is based on the Tanimoto similarity between fingerprints so that all molecules in a cluster are more similar to the centroid than a pre-defined threshold but are potentially less similar to each other. This should result in small but homogenuous clusters. The steps to the algorithm are:
# 1. Calculate a fingerprint (e.g. Morgan fingerprint) for each molecule in the dataset.
# 2. Calculate the Tanimoto distance matrix
# 3. Cluster with the Taylor-Butina algorithm:
#     1. Centroids are initiated and sorted based on number of neighbors (Tanimoto similarity above (distance below) certain threshold).
#     2. The centroid with the most neighbors gets all those assigned in its cluster.
#     3. Move to the next biggest centroid group and assign.
#     4. Repeat until no molecules with neighbors left (can have singletons - molecules without neighbors not assigned to a cluster)
#
# With this algorithm one can get molecules in one cluster that are actually more similar to another cluster's centroid but were first assigned the biggest one. Thus, the choice of threshold is an important parameter to tune.

# %%
from rdkit.ML.Cluster import Butina
from rdkit.Chem import rdMolDescriptors

# %%
mols = antiinfl['mol'].tolist()

# %% [markdown]
# #### 1. Calculate fingerprints for all molecules in the dataset.
# We have done this many times before. Let's to it again using a list comprehension in one line of code.
#
# As a reminder - the structure of a list comprehension is:
# ```
# [function(item) for item in iterable]
# ```

# %%
fp_list =  #TODO code here (FP: radius 2 and 2048 bits)

# %%
# check data type of the first element
assert type(fp_list[0]) == DataStructs.cDataStructs.ExplicitBitVect

# %% [markdown]
# #### 2. Calculate the Tanimoto distance matrix
#
# We will use the [`DataStructs.BulkTanimotoSimilarity`](http://www.dalkescientific.com/writings/diary/archive/2020/10/02/using_rdkit_bulktanimotosimilarity.html) function from the `rdkit` package to calculate the Tanimoto similarity between all pairs of fingerprints. The Tanimoto similarity is a measure of how similar two sets are so we need to convert to distances by subtracting from 1 after.
#
# This function calculates the Tanimoto similarity between all pairs of fingerprints in the dataset. The output is a list of lists where the element at position (i, j) is the Tanimoto similarity between the fingerprints of molecule i and molecule j. Try to get the Tanimoto distance between the first molecule to all the others (including intself).

# %%
sims = # TODO code here
sims

# %% [markdown]
# We can see that the first element, as expected, gives similarity of one since it is the same molecule. The other values are between 0 and 1. The closer to 1 the more similar the molecules are. The function returns a list. We will build this list so that is a triangular distance matrix in the form of a list (so all rows are not the same length and concatenated). Write a loop to calculate the Tanimoto distance matrix where at every step you calculate the similarities between the current element and all *previous* elements.

# %%
dists = []
nfps = len(fp_list)
for i in range(1,nfps):
    sims = # TODO code here: similarity between i-th molecule and all previous ones
    # convert similarity to dinstance (1-x)
    dists.extend([1-x for x in sims])
len(dists)

# %% [markdown]
# #### 3. Apply the Taylor-Butina algorithm
#
# Check out the function docs [here](https://www.rdkit.org/docs/source/rdkit.ML.Cluster.Butina.html). The arguments that need to be passed are the following:
# - `distances`: The distance matrix calculated in the previous step.
# - `n`: The number of molecules in the dataset.
# - `cutoff`: The Tanimoto similarity threshold to assign molecules to a cluster.
# - `isDistData`: A boolean indicating whether the input is a distance matrix or similarity matrix.

# %%
mol_clusters = Butina.ClusterData(
    data = # TODO code here
    nPts = # TODO code here
    distThresh = # TODO code here (pick a reasonable Tanimoto cutoff for clustering)
    isDistData = # TODO True or False?
    )
len(mol_clusters), type(mol_clusters)

# %% [markdown]
# Great! Now we have all the necessary parts to combine it all in one function that takes in as arguments the list of molecules and a given threshold and returns the list of cluster IDs (corresponding to the molecule list) and a the returned tuple of cluster indices sorted by cluster size.

# %%
def butina_cluster(mol_list,cutoff=0.35):
    '''
    Carry out Tayloer-Butina algorithm.

    :param mol_list: list of RDKit molecules
    :param cutoff: Tanimoto cutoff value for clustering

    :return: list of cluster IDs for each molecule, dictionary with cluster ID -> [molecule indices]
    '''
    # 1. get fingerprint
    fp_list = # TODO code here to get fingerprints (radius 2, 2048 bits) from molecules in a list
    dists = []
    nfps = len(fp_list)

    # 2. get tanimoto distance matrix
    for i in range(1,nfps):
        sims = # TODO get BulkTanimotoSimilarity of the i-th fingerprint with all previous ones
        # convert similarity to dinstance (1-x)
        dists.extend([1-x for x in sims])

    # 3. apply Taylor-Butina algorithm (the rest happens under the hood)
    mol_clusters = # TODO code here
    cluster_id_list = [0]*nfps
    for idx,cluster in enumerate(mol_clusters,1):
        for member in cluster:
            cluster_id_list[member] = idx

    # get tuple sorted: cluster_id -> [molecule indices]
    mol_clusters = sorted(mol_clusters, key=len, reverse=True)

    return cluster_id_list, mol_clusters

# %%
antiinfl['butina_cluster'], cluster_dict = # TODO apply the function

# %%
# Plot the size of the clusters vs. their index
fig, ax = plt.subplots(figsize=(15, 4))
ax.set_xlabel("Cluster index")
ax.set_ylabel("Number of molecules")
ax.bar(range(1, len(cluster_dict) + 1), [len(c) for c in cluster_dict], lw=5);

# %% [markdown]
# We already addressed that the threshold determines how the clusters are built and is thus a parameter worth exploring. Before, we chose a random threshold (default value of 0.35) and can see that this clustering does not give good cluster sizes. In the following cell we will iterate over a range of thresholds and plot the cluster sizes sorted by size. Based on that we can select our optimal threshold. We want a smooth distribution while at the same time have as little singletons (clusters with one data point) as possible.

# %%
for cutoff in np.arange(0.0, 1.0, 0.1):
    _, cluster_dict = butina_cluster(mols, cutoff=cutoff)
    fig, ax = plt.subplots(figsize=(15, 4))
    ax.set_title(f"Threshold: {cutoff:3.1f}")
    ax.set_xlabel("Cluster index")
    ax.set_ylabel("Number of molecules")
    ax.bar(range(1, len(cluster_dict) + 1), [len(c) for c in cluster_dict], lw=5)

# %% [markdown]
# Let's choose the best threshold based on the criteria we defined above.

# %%
mols = antiinfl['mol'].tolist()
best_cutoff = # TODO code here
antiinfl['butina_cluster'], cluster_dict = butina_cluster(mols, cutoff=best_cutoff)

# %% [markdown]
# Let's plot another interactive map as done before.

# %%
fig_pca = px.scatter(antiinfl,
                     x="PCA-1",
                     y="PCA-2",
                     color='butina_cluster',
                     title='PCA of morgan fingerprints',
                     labels={'color': 'butina_cluster'},
                     width=1200,
                     height=800)

app_pca = molplotly.add_molecules(fig=fig_pca,
                                  df=antiinfl,
                                  smiles_col='Smiles',
                                  title_col='Name',
                                  caption_cols=['USAN Definition', 'cluster_opt', 'butina_cluster'],
                                  color_col='butina_cluster',
                                  show_coords=False)

app_pca.run_server(mode='inline', port=8700, height=850)

# %% [markdown]
# Because we have a lot of small clusters, the plot above is difficult to analyze. Let's visualize some molecules and see if the clustering makes sense to us from a chemistry perspective.

# %%
from rdkit.Chem import Draw
print("Ten molecules from largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [mols[i] for i in cluster_dict[0][:10]],
    molsPerRow=5,
)

# %%
print("Ten molecules from second largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [mols[i] for i in cluster_dict[1][:10]],
    molsPerRow=5,
)

# %%
print("Ten molecules from third largest cluster:")
# Draw molecules
Draw.MolsToGridImage(
    [mols[i] for i in cluster_dict[2][:10]],
    molsPerRow=5,
)

# %% [markdown]
# I would argue that the three visualized clusters certainly show similarity between the molecules. Well done! This analysis is only one aspect and depending on the objective can be handled differently. But clustering and visualizing the data will help with getting a sense of what you are working with and if your data processing for a project can makes sense.
