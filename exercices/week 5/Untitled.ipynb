# %%
import pandas as pd

drugs = pd.read_csv("data1.csv", sep= ";")

print("Shape", drugs.shape)
print("Columns", drugs.columns)
# Out:
# Shape (3, 30)
# Columns Index(['Creme', 'Parent Molecule', 'Name', 'Synonyms', 'Research Codes',
#        'Phase', 'Drug Applicants', 'USAN Stem', 'USAN Year', 'USAN Definition',
#        'USAN Stem - Substem', 'First Approval', 'ATC Codes',
#        'Level 4 ATC Codes', 'Level 3 ATC Codes', 'Level 2 ATC Codes',
#        'Level 1 ATC Codes', 'Indication Class', 'Patent', 'Drug Type',
#        'Passes Rule of Five', 'First In Class', 'Chirality', 'Prodrug', 'Oral',
#        'Parenteral', 'Topical', 'Black Box', 'Availability Type', 'Smiles'],
#       dtype='object')

# %%
#approved_drugs = drugs[(drugs["Smiles"].notnull())]

# %%
from rdkit.Chem import PandasTools

PandasTools.RenderImagesInAllDataFrames(images = True) # needed to render images if you run the cell multiple times

PandasTools.AddMoleculeColumnToFrame(approved_drugs, smilesCol = "Smiles", molCol = "RdkitMOL")

# %%
drugs.head(3)
# Out:
# /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages/rdkit/Chem/PandasPatcher.py:137: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#    Creme Parent Molecule         Name  \
# 0  Nivea    CHEMBL492491  FENVALERATE
# 1  Nivea        Glycerin     Glycerin
# 2  Nivea   CHEMBL2103777  THIOPHANATE
#
#                                             Synonyms  \
# 0  BELMARK|FENVALERATE|PHENVALERATE|PYDRIN|S-5602...
# 1                       Glycerol, 1,2,3-propanetriol
# 2                             NSC-170810|THIOPHANATE
#
#              Research Codes  Phase  Drug Applicants  USAN Stem  USAN Year  \
# 0  S-5602|SD-43775|WL-43775   -1.0              NaN        NaN        NaN
# 1                       NaN    NaN              NaN        NaN        NaN
# 2                NSC-170810   -1.0              NaN        NaN        NaN
#
#    USAN Definition  ...  Passes Rule of Five  First In Class  \
# 0              NaN  ...                    0               0
# 1              NaN  ...                  Yes              No
# 2              NaN  ...                    1               0
#
#           Chirality Prodrug Oral Parenteral Topical  Black Box  \
# 0   Racemic Mixture       0    0          0       0          0
# 1   Racemic mixture      No  Yes        Yes     Yes         No
# 2  Achiral Molecule       0    0          0       0          0
#
#    Availability Type                                             Smiles
# 0            Unknown  CC(C)C(C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1)c1ccc(C...
# 1                OTC                                         C(C(CO)O)O
# 2            Unknown             CCOC(=O)NC(=S)Nc1ccccc1NC(=S)NC(=O)OCC
#
# [3 rows x 30 columns]

# %%
approved_drugs = drugs[(drugs["Parent Molecule"]=="Glycerin")]
approved_drugs
# Out:
# /Users/victoire/miniconda3/envs/ppchem/lib/python3.10/site-packages/rdkit/Chem/PandasPatcher.py:137: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   for col in df_subset.columns[df_subset.applymap(MolFormatter.is_mol).any()]
#    Creme Parent Molecule      Name                      Synonyms  \
# 1  Nivea        Glycerin  Glycerin  Glycerol, 1,2,3-propanetriol
#
#   Research Codes  Phase  Drug Applicants  USAN Stem  USAN Year  \
# 1            NaN    NaN              NaN        NaN        NaN
#
#    USAN Definition  ...  Passes Rule of Five  First In Class        Chirality  \
# 1              NaN  ...                  Yes              No  Racemic mixture
#
#   Prodrug Oral Parenteral Topical  Black Box  Availability Type      Smiles
# 1      No  Yes        Yes     Yes         No                OTC  C(C(CO)O)O
#
# [1 rows x 30 columns]
